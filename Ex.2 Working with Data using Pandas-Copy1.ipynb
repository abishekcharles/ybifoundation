# %%
Q1:Import the dataset

# %%
import pandas as pd
df = pd.read_csv("candy.csv")
df
# Out:
#     id              competitorname chocolate fruity caramel peanutyalmondy  \
# 0    0                   100 Grand       Yes     No     Yes             No
# 1    1                3 Musketeers       Yes     No      No             No
# 2    2                   Air Heads        No    Yes      No             No
# 3    3                  Almond Joy       Yes     No      No            Yes
# 4    4                   Baby Ruth       Yes     No     Yes            Yes
# ..  ..                         ...       ...    ...     ...            ...
# 78  78                   Twizzlers        No    Yes      No             No
# 79  79                    Warheads        No    Yes      No             No
# 80  80        Welch's Fruit Snacks        No    Yes      No             No
# 81  81  Werther's Original Caramel        No     No     Yes             No
# 82  82                    Whoppers       Yes     No      No             No
#
# ...

# %%
Q2:Display the head and tail of the dataset

# %%
df.head()
# Out:
#    id competitorname chocolate fruity caramel peanutyalmondy nougat  \
# 0   0      100 Grand       Yes     No     Yes             No     No
# 1   1   3 Musketeers       Yes     No      No             No    Yes
# 2   2      Air Heads        No    Yes      No             No     No
# 3   3     Almond Joy       Yes     No      No            Yes     No
# 4   4      Baby Ruth       Yes     No     Yes            Yes    Yes
#
#   crispedricewafer hard  bar pluribus  sugarpercent  pricepercent  winpercent
# 0              Yes   No  Yes       No         0.732         0.860   66.971725
# 1               No   No  Yes       No         0.604         0.511   67.602936
# 2               No   No   No       No         0.906         0.511   52.341465
# 3               No   No  Yes       No         0.465         0.767   50.347546
# 4               No   No  Yes       No         0.604         0.767   56.914547

# %%
df.tail()
# Out:
#     id              competitorname chocolate fruity caramel peanutyalmondy  \
# 78  78                   Twizzlers        No    Yes      No             No
# 79  79                    Warheads        No    Yes      No             No
# 80  80        Welch's Fruit Snacks        No    Yes      No             No
# 81  81  Werther's Original Caramel        No     No     Yes             No
# 82  82                    Whoppers       Yes     No      No             No
#
#    nougat crispedricewafer hard bar pluribus  sugarpercent  pricepercent  \
# 78     No               No   No  No       No         0.220         0.116
# 79     No               No  Yes  No       No         0.093         0.116
# 80     No               No   No  No      Yes         0.313         0.313
# 81     No               No  Yes  No       No         0.186         0.267
# 82     No              Yes   No  No      Yes         0.872         0.848
#
#     winpercent
# 78   45.466282
# 79   39.011898
# 80   44.375519
# ...

# %%
Q3:Display the column names and datatypes of the columns

# %%
df.columns
# Out:
# Index(['id', 'competitorname', 'chocolate', 'fruity', 'caramel',
#        'peanutyalmondy', 'nougat', 'crispedricewafer', 'hard', 'bar',
#        'pluribus', 'sugarpercent', 'pricepercent', 'winpercent'],
#       dtype='object')

# %%
df.dtypes
# Out:
# id                    int64
# competitorname       object
# chocolate            object
# fruity               object
# caramel              object
# peanutyalmondy       object
# nougat               object
# crispedricewafer     object
# hard                 object
# bar                  object
# pluribus             object
# sugarpercent        float64
# pricepercent        float64
# winpercent          float64
# dtype: object

# %%
Q4:Display statistical information about suitable columns

# %%
df.describe
# Out:
# <bound method NDFrame.describe of     id              competitorname chocolate fruity caramel peanutyalmondy  \
# 0    0                   100 Grand       Yes     No     Yes             No
# 1    1                3 Musketeers       Yes     No      No             No
# 2    2                   Air Heads        No    Yes      No             No
# 3    3                  Almond Joy       Yes     No      No            Yes
# 4    4                   Baby Ruth       Yes     No     Yes            Yes
# ..  ..                         ...       ...    ...     ...            ...
# 78  78                   Twizzlers        No    Yes      No             No
# 79  79                    Warheads        No    Yes      No             No
# 80  80        Welch's Fruit Snacks        No    Yes      No             No
# 81  81  Werther's Original Caramel        No     No     Yes             No
# 82  82                    Whoppers       Yes     No      No             No
#
# ...

# %%
Q5:Display all the rows of the columns 'chocolate', 'caramel', and␣ 'fruity'

# %%
print(df[['chocolate', 'caramel', 'fruity']].to_string())
# Out:
#    chocolate caramel fruity
# 0        Yes     Yes     No
# 1        Yes      No     No
# 2         No      No    Yes
# 3        Yes      No     No
# 4        Yes     Yes     No
# 5         No      No     No
# 6         No      No     No
# 7         No     Yes    Yes
# 8        Yes      No     No
# 9         No      No    Yes
# 10        No      No    Yes
# 11        No      No    Yes
# 12        No      No    Yes
# 13        No      No    Yes
# 14        No      No    Yes
# 15        No      No    Yes
# 16        No      No    Yes
# 17        No      No     No
# 18        No      No    Yes
# 19        No      No    Yes
# 20       Yes      No     No
# 21       Yes      No     No
# 22       Yes      No     No
# 23       Yes      No     No
# 24        No      No    Yes
# 25       Yes      No     No
# 26       Yes      No     No
# 27        No      No    Yes
# 28        No      No    Yes
# 29        No      No    Yes
# 30       Yes      No     No
# 31       Yes      No     No
# ...

# %%
Q6:Display the total number of competitors

# %%
total_competitors = df.shape[0]
print("\nTotal number of competitors:", total_competitors)
# Out:
# Total number of competitors: 83

# %%
Q7:Display by slicing the dataset using iloc and loc commands

# %%
print("\nDataset using iloc (rows 0 to 4):")
print(df.iloc[:5])
# Out:
# Dataset using iloc (rows 0 to 4):
#    id competitorname chocolate fruity caramel peanutyalmondy nougat  \
# 0   0      100 Grand       Yes     No     Yes             No     No
# 1   1   3 Musketeers       Yes     No      No             No    Yes
# 2   2      Air Heads        No    Yes      No             No     No
# 3   3     Almond Joy       Yes     No      No            Yes     No
# 4   4      Baby Ruth       Yes     No     Yes            Yes    Yes
#
#   crispedricewafer hard  bar pluribus  sugarpercent  pricepercent  winpercent
# 0              Yes   No  Yes       No         0.732         0.860   66.971725
# 1               No   No  Yes       No         0.604         0.511   67.602936
# 2               No   No   No       No         0.906         0.511   52.341465
# 3               No   No  Yes       No         0.465         0.767   50.347546
# 4               No   No  Yes       No         0.604         0.767   56.914547

# %%
print(df.loc[7])
# Out:
# id                                   7
# competitorname      Caramel Apple Pops
# chocolate                           No
# fruity                             Yes
# caramel                            Yes
# peanutyalmondy                      No
# nougat                              No
# crispedricewafer                    No
# hard                                No
# bar                                 No
# pluribus                            No
# sugarpercent                     0.604
# pricepercent                     0.325
# winpercent                   34.517681
# Name: 7, dtype: object

# %%
Q8:Check the dataset for any null value and fill the null value with 0.01

# %%
print("Abishek Charles V")
print("URK21CS1053")
df.isnull()
# Out:
# Abishek Charles V
# URK21CS1053
#        id  competitorname  chocolate  fruity  caramel  peanutyalmondy  nougat  \
# 0   False           False      False   False    False           False   False
# 1   False           False      False   False    False           False   False
# 2   False           False      False   False    False           False   False
# 3   False           False      False   False    False           False   False
# 4   False           False      False   False    False           False   False
# ..    ...             ...        ...     ...      ...             ...     ...
# 78  False           False      False   False    False           False   False
# 79  False           False      False   False    False           False   False
# 80  False           False      False   False    False           False   False
# 81  False           False      False   False    False           False   False
# 82  False           False      False   False    False           False   False
#
# ...

# %%
print("Abishek Charles V")
print("URK21CS1053")
df.fillna(0.01)
# Out:
# Abishek Charles V
# URK21CS1053
#     id              competitorname chocolate fruity caramel peanutyalmondy  \
# 0    0                   100 Grand       Yes     No     Yes             No
# 1    1                3 Musketeers       Yes     No      No             No
# 2    2                   Air Heads        No    Yes      No             No
# 3    3                  Almond Joy       Yes     No      No            Yes
# 4    4                   Baby Ruth       Yes     No     Yes            Yes
# ..  ..                         ...       ...    ...     ...            ...
# 78  78                   Twizzlers        No    Yes      No             No
# 79  79                    Warheads        No    Yes      No             No
# 80  80        Welch's Fruit Snacks        No    Yes      No             No
# 81  81  Werther's Original Caramel        No     No     Yes             No
# 82  82                    Whoppers       Yes     No      No             No
#
# ...

# %%
Q9:Find the mean winpercent

# %%
print("Abishek Charles V")
print("URK21CS1053")
df['winpercent'].mean()
# Out:
# Abishek Charles V
# URK21CS1053
# 50.58490762650603

# %%
Q10:Display how many competitors are both Chocolate and fruity

# %%
print("Abishek Charles V")
print("URK21CS1053")
print(df[(df['chocolate']=='Yes')&(df['fruity']=='Yes')])
# Out:
# Abishek Charles V
# URK21CS1053
#     id competitorname chocolate fruity caramel peanutyalmondy nougat  \
# 72  72    Tootsie Pop       Yes    Yes      No             No     No
#
#    crispedricewafer hard bar pluribus  sugarpercent  pricepercent  winpercent
# 72               No  Yes  No       No         0.604         0.325   48.982651

# %%
Q11:Display how many competitors are both hard and bar

# %%
print("Abishek Charles V")
print("URK21CS1053")
print(df[(df['hard']=='Yes')&(df['bar']=='Yes')])
# Out:
# Abishek Charles V
# URK21CS1053
# Empty DataFrame
# Columns: [id, competitorname, chocolate, fruity, caramel, peanutyalmondy, nougat, crispedricewafer, hard, bar, pluribus, sugarpercent, pricepercent, winpercent]
# Index: []

# %%
Q12:Display which competitor has the highest win percent

# %%
print("Abishek Charles V")
print("URK21CS1053")
df.loc[df['winpercent'].idxmax()]['competitorname']
# Out:
# Abishek Charles V
# URK21CS1053
# "Reese's Peanut Butter cup"

# %%
Q13:Sort the competitors by winpercent

# %%
print("Abishek Charles V")
print("URK21CS1053")
print(df.sort_values(by='winpercent')['competitorname'].to_string())
# Out:
# Abishek Charles V
# URK21CS1053
# 42                      Nik L Nip
# 5              Boston Baked Beans
# 10                       Chiclets
# 70                   Super Bubble
# 24                     Jawbusters
# 55              Root Beer Barrels
# 69                    Sugar Daddy
# 68                   Sugar Babies
# 17              Haribo Happy Cola
# 7              Caramel Apple Pops
# 67            Strawberry bon bons
# 57                        Sixlets
# 53                       Ring pop
# 9      Chewey Lemonhead Fruit Mix
# 48                      Red vines
# 46                   Pixie Sticks
# 60                Nestle Smarties
# 6                      Candy Corn
# 8                 Charleston Chew
# 79                       Warheads
# 28                      Lemonhead
# 14                        Fun Dip
# 43                    Now & Later
# 12                       Dum Dums
# 47                      Pop Rocks
# 27                    Laffy Taffy
# ...

# %%
Result:
    Thus the python programs are executed successfully and the output is verified.
